# %%
# get data from RESTful API in METADB
import requests
import json
import time
import numpy as np

from functools import wraps

URL = 'http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com'
USER = 'chunlab@chunlab.com'
TOKEN = None

def _token(user=USER):
    url = URL+"/TOKENS"
    body = "{\"userid\":\"%s\"}" %user
    response = requests.request("POST", url, data=body)
    token = json.loads(response.text)
    return token

def _headers():
    token = TOKEN
    headers = {
        "Content-type":"application/json",
        "x-cl-token":token['token']
    }
    return headers

def api_timer(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        t1 = time.time()
        result = func(*args, **kwargs)
        t2 = time.time() - t1
        print('%s takes %f secs.' %(func.__name__, t2))
        return result
    return wrapper

def api_wrapper(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        global TOKEN
        #if args
        try:
            if TOKEN is None:
                TOKEN = _token(user)
            res = func(*args, **kwargs)
            time.sleep(0.001)
            print('%s succeeded' %(func.__name__))
        except:
            try:
                TOKEN = _token(user)
                res = func(*args, **kwargs)
                time.sleep(0.001)
                print('%s succeeded' %(func.__name__))
            except:
                res = None
                time.sleep(0.001)
                raise RuntimeError('%s failed' %(func.__name__))

        return res

    return wrapper

def get_profiles(mtp_ids, user=USER):#, greengene=False
    profiles = [get_profile(mtp_id, user) for mtp_id in mtp_ids]        
    return profiles

@api_timer
@api_wrapper
def get_profile(mtp_id, user=USER):#, greengene=False
    url = URL+"/USERS/%s/SAMPLES/%s/PROFILE" %(user, mtp_id)
    #if greengene:
    #    url += '?UseQIIME'
    headers = _headers()
    response = requests.request("GET", url, headers=headers)
    res = json.loads(response.text)
    return res


def get_token(user=USER):
    url = URL+"/TOKENS"
    body = "{\"userid\":\"%s\"}" %user
    response = requests.request("POST", url, data=body)
    token = json.loads(response.text)
    return token

def _headers_with_token(token):
    headers = {
        "Content-type":"application/json",
        "x-cl-token":token['token'] if type(token)==dict else token
    }
    return headers

def get_samples(token, user=USER):
    url = URL+"/USERS/%s/SAMPLES" %(user)
    headers = _headers_with_token(token)
    
    try:
        response = requests.request("GET", url, headers=headers)
        res = json.loads(response.text)
        time.sleep(0.001)
        print('getting samples succeeded: %s' %url)

    except:
        res = None
        time.sleep(0.001)
        raise RuntimeError('getting samples failed: %s' %url)

    return res


#METADB API
def search_ezbiocloud_samples(token, where):
    url = URL+"/METADB/SAMPLES?%s" %where
    headers = _headers_with_token(token)

    try:
        response = requests.request("GET", url, headers=headers)
        res = json.loads(response.text)
        print('searching samples succeeded: %s' %url)

    except:
        res = None
        time.sleep(0.001)
        raise RuntimeError('searching samples failed: %s' %url)
        
    return res

# %%
import time
import pickle
import json
import os
def download_project(prj_num):
    check_sample=1
    loop_idx=0
    idx=1
    while check_sample==1:
        sample_name="CL"+str(prj_num)+"S"+str(idx)
        if loop_idx % 1000 == 0:
            TOKEN = get_token(user=USER)

        prof = get_profile(sample_name,user=USER)
        try:
            print(prof['code'])
            #print('project '+prj_num+' complete')
            check_sample=0
        except:
            meta = search_ezbiocloud_samples(TOKEN,'mtp_id='+sample_name)
            t_sample = Sample(prof,meta)
            
            # save as pickle
            with open("PROJ"+str(prj_num)+".pkl","a+b") as f1:
                pickle.dump(t_sample,f1,pickle.HIGHEST_PROTOCOL)
                # it works quite well
            
            # save as json
            '''
            with open("PROJ"+str(prj_num)+".json","a+") as f2:
                json.dump(t_sample.toJSON(),f2)
                # not that well...
            '''
            # save as h5?
            del t_sample
                
            idx=idx+1
            time.sleep(0.04)

        loop_idx = loop_idx+1


TOKEN = get_token(user=USER)
for i in range(1,474):
    if os.path.isfile("./PROJ"+str(i)+".pkl"):
        print("file_exist")
        os.remove("./PROJ"+str(i)+".pkl")
        download_project(i)
    else:
        download_project(i)
#prof =
# Out:
# get_profile succeeded
# get_profile takes 0.075380 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S1
# deleting object
# get_profile succeeded
# get_profile takes 0.124617 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S2
# deleting object
# get_profile succeeded
# get_profile takes 0.087887 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S3
# deleting object
# get_profile succeeded
# get_profile takes 0.114884 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S4
# deleting object
# get_profile succeeded
# get_profile takes 0.118587 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S5
# deleting object
# get_profile succeeded
# get_profile takes 0.080567 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S6
# deleting object
# get_profile succeeded
# get_profile takes 0.102683 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S7
# deleting object
# get_profile succeeded
# get_profile takes 0.098183 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S8
# deleting object
# get_profile succeeded
# get_profile takes 0.084450 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S9
# deleting object
# get_profile succeeded
# get_profile takes 0.086098 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S10
# deleting object
# get_profile succeeded
# get_profile takes 0.080362 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S11
# deleting object
# get_profile succeeded
# get_profile takes 0.081380 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S12
# deleting object
# get_profile succeeded
# get_profile takes 0.092821 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S13
# deleting object
# get_profile succeeded
# get_profile takes 0.094793 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S14
# deleting object
# get_profile succeeded
# get_profile takes 0.077042 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S15
# deleting object
# get_profile succeeded
# get_profile takes 0.117146 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S16
# deleting object
# get_profile succeeded
# get_profile takes 0.075507 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S17
# deleting object
# get_profile succeeded
# get_profile takes 0.071775 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S18
# deleting object
# get_profile succeeded
# get_profile takes 0.200397 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S19
# deleting object
# get_profile succeeded
# get_profile takes 0.101108 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S20
# deleting object
# get_profile succeeded
# get_profile takes 0.250863 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S21
# deleting object
# get_profile succeeded
# get_profile takes 0.099111 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S22
# deleting object
# get_profile succeeded
# get_profile takes 0.107837 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S23
# deleting object
# get_profile succeeded
# get_profile takes 0.074325 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S24
# deleting object
# get_profile succeeded
# get_profile takes 0.069549 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S25
# deleting object
# get_profile succeeded
# get_profile takes 0.100072 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S26
# deleting object
# get_profile succeeded
# get_profile takes 0.073664 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S27
# deleting object
# get_profile succeeded
# get_profile takes 0.095086 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S28
# deleting object
# get_profile succeeded
# get_profile takes 0.100447 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S29
# deleting object
# get_profile succeeded
# get_profile takes 0.085490 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S30
# deleting object
# get_profile succeeded
# get_profile takes 0.092492 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S31
# deleting object
# get_profile succeeded
# get_profile takes 0.077531 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S32
# deleting object
# get_profile succeeded
# get_profile takes 0.101736 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S33
# deleting object
# get_profile succeeded
# get_profile takes 0.095095 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S34
# deleting object
# get_profile succeeded
# get_profile takes 0.082054 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S35
# deleting object
# get_profile succeeded
# get_profile takes 0.105933 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S36
# deleting object
# get_profile succeeded
# get_profile takes 0.097454 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S37
# deleting object
# get_profile succeeded
# get_profile takes 0.110770 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S38
# deleting object
# get_profile succeeded
# get_profile takes 0.112622 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S39
# deleting object
# get_profile succeeded
# get_profile takes 0.100828 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S40
# deleting object
# get_profile succeeded
# get_profile takes 0.092169 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S41
# deleting object
# get_profile succeeded
# get_profile takes 0.086150 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S42
# deleting object
# get_profile succeeded
# get_profile takes 0.096260 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S43
# deleting object
# get_profile succeeded
# get_profile takes 0.079569 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S44
# deleting object
# get_profile succeeded
# get_profile takes 0.077765 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S45
# deleting object
# get_profile succeeded
# get_profile takes 0.096171 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S46
# deleting object
# get_profile succeeded
# get_profile takes 0.083291 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S47
# deleting object
# get_profile succeeded
# get_profile takes 0.089864 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S48
# deleting object
# get_profile succeeded
# get_profile takes 0.084818 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S49
# deleting object
# get_profile succeeded
# get_profile takes 0.076471 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S50
# deleting object
# get_profile succeeded
# get_profile takes 0.119297 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S51
# deleting object
# get_profile succeeded
# get_profile takes 0.094230 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S52
# deleting object
# get_profile succeeded
# get_profile takes 0.104576 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S53
# deleting object
# get_profile succeeded
# get_profile takes 0.094092 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S54
# deleting object
# get_profile succeeded
# get_profile takes 0.089620 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S55
# deleting object
# get_profile succeeded
# get_profile takes 0.067360 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S56
# deleting object
# get_profile succeeded
# get_profile takes 0.092472 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S57
# deleting object
# get_profile succeeded
# get_profile takes 0.078079 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S58
# deleting object
# get_profile succeeded
# get_profile takes 0.094683 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S59
# deleting object
# get_profile succeeded
# get_profile takes 0.081177 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S60
# deleting object
# get_profile succeeded
# get_profile takes 0.082479 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S61
# deleting object
# get_profile succeeded
# get_profile takes 0.098742 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S62
# deleting object
# get_profile succeeded
# get_profile takes 0.099804 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S63
# deleting object
# get_profile succeeded
# get_profile takes 0.108511 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S64
# deleting object
# get_profile succeeded
# get_profile takes 0.094795 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S65
# deleting object
# get_profile succeeded
# get_profile takes 0.109438 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S66
# deleting object
# get_profile succeeded
# get_profile takes 0.083550 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S67
# deleting object
# get_profile succeeded
# get_profile takes 0.076957 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S68
# deleting object
# get_profile succeeded
# get_profile takes 0.082163 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S69
# deleting object
# get_profile succeeded
# get_profile takes 0.080513 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S70
# deleting object
# get_profile succeeded
# get_profile takes 0.116754 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S71
# deleting object
# get_profile succeeded
# get_profile takes 0.095977 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S72
# deleting object
# get_profile succeeded
# get_profile takes 0.097984 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S73
# deleting object
# get_profile succeeded
# get_profile takes 0.080616 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S74
# deleting object
# get_profile succeeded
# get_profile takes 0.086340 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S75
# deleting object
# get_profile succeeded
# get_profile takes 0.096681 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S76
# deleting object
# get_profile succeeded
# get_profile takes 0.071224 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S77
# deleting object
# get_profile succeeded
# get_profile takes 0.090312 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S78
# deleting object
# get_profile succeeded
# get_profile takes 0.092549 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S79
# deleting object
# get_profile succeeded
# get_profile takes 0.083800 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S80
# deleting object
# get_profile succeeded
# get_profile takes 0.103081 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S81
# deleting object
# get_profile succeeded
# get_profile takes 0.098596 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S82
# deleting object
# get_profile succeeded
# get_profile takes 0.067899 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S83
# deleting object
# get_profile succeeded
# get_profile takes 0.104039 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S84
# deleting object
# get_profile succeeded
# get_profile takes 0.102978 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S85
# deleting object
# get_profile succeeded
# get_profile takes 0.075135 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S86
# deleting object
# get_profile succeeded
# get_profile takes 0.080261 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S87
# deleting object
# get_profile succeeded
# get_profile takes 0.081713 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S88
# deleting object
# get_profile succeeded
# get_profile takes 0.110814 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S89
# deleting object
# get_profile succeeded
# get_profile takes 0.076662 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S90
# deleting object
# get_profile succeeded
# get_profile takes 0.086931 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S91
# deleting object
# get_profile succeeded
# get_profile takes 0.102871 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S92
# deleting object
# get_profile succeeded
# get_profile takes 0.071593 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S93
# deleting object
# get_profile succeeded
# get_profile takes 0.131228 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S94
# deleting object
# get_profile succeeded
# get_profile takes 0.088251 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S95
# deleting object
# get_profile succeeded
# get_profile takes 0.082298 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S96
# deleting object
# get_profile succeeded
# get_profile takes 0.100959 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S97
# deleting object
# get_profile succeeded
# get_profile takes 0.088296 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S98
# deleting object
# get_profile succeeded
# get_profile takes 0.092190 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S99
# deleting object
# get_profile succeeded
# get_profile takes 0.093099 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S100
# deleting object
# get_profile succeeded
# get_profile takes 0.104311 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S101
# deleting object
# get_profile succeeded
# get_profile takes 0.090470 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S102
# deleting object
# get_profile succeeded
# get_profile takes 0.094289 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S103
# deleting object
# get_profile succeeded
# get_profile takes 0.083836 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S104
# deleting object
# get_profile succeeded
# get_profile takes 0.089293 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S105
# deleting object
# get_profile succeeded
# get_profile takes 0.105906 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S106
# deleting object
# get_profile succeeded
# get_profile takes 0.096600 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S107
# deleting object
# get_profile succeeded
# get_profile takes 0.096283 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S108
# deleting object
# get_profile succeeded
# get_profile takes 0.092365 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S109
# deleting object
# get_profile succeeded
# get_profile takes 0.109466 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S110
# deleting object
# get_profile succeeded
# get_profile takes 0.096916 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S111
# deleting object
# get_profile succeeded
# get_profile takes 0.100875 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S112
# deleting object
# get_profile succeeded
# get_profile takes 0.083292 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S113
# deleting object
# get_profile succeeded
# get_profile takes 0.148040 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S114
# deleting object
# get_profile succeeded
# get_profile takes 0.072902 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S115
# deleting object
# get_profile succeeded
# get_profile takes 0.087565 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S116
# deleting object
# get_profile succeeded
# get_profile takes 0.088822 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S117
# deleting object
# get_profile succeeded
# get_profile takes 0.120827 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S118
# deleting object
# get_profile succeeded
# get_profile takes 0.129139 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S119
# deleting object
# get_profile succeeded
# get_profile takes 0.090432 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL1S120
# deleting object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-06089a5ce4cb> in download_project(prj_num)
#      15         try:
# ---> 16             print(prof['code'])
#      17             #print('project '+prj_num+' complete')
#
# TypeError: list indices must be integers or slices, not str
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-178-06089a5ce4cb> in <module>()
#      48         download_project(i)
#      49     else:
# ---> 50         download_project(i)
#      51 #prof =
#
# <ipython-input-178-06089a5ce4cb> in download_project(prj_num)
#      36
#      37             idx=idx+1
# ---> 38             time.sleep(0.04)
#      39
#      40         loop_idx = loop_idx+1
#
# KeyboardInterrupt:

# %%
# since meta.keys() are different project by project --> use all keys
#meta_key = ['mtp_id','sample_id','host_sex','host_age','host_life_stage','host_nation','tag_region','platform','category','ee']
import pickle

class Sample:
    # constructor
    def __init__(self,profile,meta):
        try:
            self.meta = meta[0] #since meta_api returns [{k-v,k-v ..}] form
            prof_key = ['tn','nm','p','lvl']
            self.profile = [tax['cnt'][0] for tax in profile]
            #self.key = [tax['tn'] for tax in profile]
            self.key =[{p_key : tax[p_key] for p_key in prof_key} for tax in profile]
        except:
            self.meta = None
            self.profile = None
            self.key = None
    
    
    def toJSON(self):
        return json.dumps(self, default=lambda o: o.__dict__, sort_keys=True, indent=4)
    
    
    # destructor
    def __del__(self):
        print("deleting object")
    
    # normalization part
    # todo : make function-chaining work...
    # maybe this also can be module...
    
def ratio(self): #this is test function, it will merge to normal()
    try: # initial
        ratio=np.divide(self.profile,self.profile[0])
        return list(ratio)
    except: # kind of operation chaining...?\
        print(self)
        return list(np.divide(self/self[0]))
            
        
    
    
    # alpha-div part
    # --> perhaps, we can make this into module...

# %%
TOKEN = get_token(user=USER)
t_prof = get_profile('CL3S3',user=USER)
t_meta = search_ezbiocloud_samples(TOKEN,'mtp_id=CL3S3')
#print(t_meta)
#print(t_meta)
#print(t_prof)
sample1 = Sample(t_prof,t_meta)
print(type(sample1.toJSON()))
del sample1
# Out:
# get_profile succeeded
# get_profile takes 0.091044 secs.
# searching samples succeeded: http://elb-gateway-1990213061.ap-northeast-2.elb.amazonaws.com/METADB/SAMPLES?mtp_id=CL3S3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-171-5a440e4f5fa6> in <module>()
#       6 #print(t_prof)
#       7 sample1 = Sample(t_prof,t_meta)
# ----> 8 print(type(sample1.toJSON()))
#       9 del sample1
#
# <ipython-input-169-03730ace6742> in toJSON(self)
#      19
#      20     def toJSON(self):
# ---> 21         return json.dump(self, default=lambda o: o.__dict__, sort_keys=True, indent=4)
#      22
#      23
#
# TypeError: dump() missing 1 required positional argument: 'fp'

# %%
with open('./PROJ4.pkl', 'rb') as p4:
    # when object saved in pickle format, 
    # use iterator!
    merge_profiles = pickle.load(p4)
    #print(merge_profiles.profile)
    merge_profiles = pickle.load(p4)
    #print(merge_profiles.profile)
    

for sam in open('./PROJ4.json','rb'):
    print(json.load(sam))
# Out:
# deleting object
# deleting object
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-168-2d9840131194> in <module>()
#       9
#      10 for sam in open('./PROJ4.json','rb'):
# ---> 11     print(json.load(sam))
#
# ~/anaconda3/lib/python3.6/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294
#     295     """
# --> 296     return loads(fp.read(),
#     297         cls=cls, object_hook=object_hook,
#     298         parse_float=parse_float, parse_int=parse_int,
#
# AttributeError: 'bytes' object has no attribute 'read'
